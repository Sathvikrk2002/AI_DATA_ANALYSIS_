# %%
# Title: Feature Engineering for Classification
# Description: Create a new feature that could help distinguish between species based on
# logical assumptions and verify its utility.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Add species as a categorical column
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# Create a new feature: sepal_length_to_petal_length_ratio
df['sepal_to_petal_length_ratio'] = df['sepal length (cm)'] / df['petal length (cm)']

# Display basic statistics grouped by species
print("Mean of the new feature by species:\n")
print(df.groupby('species')['sepal_to_petal_length_ratio'].mean())

# Visualize the new feature's distribution
plt.figure(figsize=(8, 5))
sns.boxplot(x='species', y='sepal_to_petal_length_ratio', data=df, palette='pastel')
plt.title("Distribution of Sepal-to-Petal Length Ratio by Species")
plt.xlabel("Species")
plt.ylabel("Sepal Length / Petal Length")
plt.tight_layout()
plt.show()
# Out:
# Mean of the new feature by species:
#
# species
# setosa        3.464906
# versicolor    1.400896
# virginica     1.188350
# Name: sepal_to_petal_length_ratio, dtype: float64
# /tmp/ipykernel_3660/2220287607.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby('species')['sepal_to_petal_length_ratio'].mean())
# /tmp/ipykernel_3660/2220287607.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal_to_petal_length_ratio', data=df, palette='pastel')
